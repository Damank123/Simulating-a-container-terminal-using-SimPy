# %%
import simpy
import random

# Constants
AVG_ARRIVAL_TIME = 5 * 60  # Average time between vessel arrivals (5 hours in minutes)
NUM_CONTAINERS = 150  # Number of containers per vessel
CRANE_TIME_PER_CONTAINER = 3  # Time to move one container (in minutes)
TRUCK_TIME = 6  # Time for a truck to drop off a container and come back (in minutes)
NUM_BERTHS = 2  # Number of berths
NUM_CRANES = 2  # Number of quay cranes
NUM_TRUCKS = 3  # Number of trucks
SIMULATION_TIME = 24 * 60  # Simulation time in minutes (24 hours)

# Initialize the random seed for reproducibility
random.seed(42)

class Terminal:
    def __init__(self, env):
        self.env = env
        self.berths = simpy.Resource(env, NUM_BERTHS)
        self.cranes = simpy.Resource(env, NUM_CRANES)
        self.trucks = simpy.Resource(env, NUM_TRUCKS)

    def berth_vessel(self, vessel):
        with self.berths.request() as request:
            yield request
            print(f"Time {self.env.now}: Vessel {vessel.id} has berthed.")
            yield self.env.process(self.unload_vessel(vessel))

    def unload_vessel(self, vessel):
        for _ in range(NUM_CONTAINERS):
            with self.cranes.request() as crane_request:
                yield crane_request
                yield self.env.timeout(CRANE_TIME_PER_CONTAINER)
                print(f"Time {self.env.now}: Crane has moved a container from Vessel {vessel.id}.")
                with self.trucks.request() as truck_request:
                    yield truck_request
                    yield self.env.timeout(TRUCK_TIME)
                    print(f"Time {self.env.now}: Truck has delivered a container from Vessel {vessel.id}.")
        print(f"Time {self.env.now}: Vessel {vessel.id} has finished unloading and is leaving.")

class Vessel:
    def __init__(self, env, terminal, id):
        self.env = env
        self.terminal = terminal
        self.id = id
        self.action = env.process(self.arrive())

    def arrive(self):
        print(f"Time {self.env.now}: Vessel {self.id} is arriving.")
        yield self.env.process(self.terminal.berth_vessel(self))

def vessel_arrivals(env, terminal):
    vessel_id = 1
    while True:
        arrival_time = random.expovariate(1.0 / AVG_ARRIVAL_TIME)
        yield env.timeout(arrival_time)
        vessel = Vessel(env, terminal, vessel_id)
        vessel_id += 1

def run_simulation(simulation_time):
    env = simpy.Environment()
    terminal = Terminal(env)
    env.process(vessel_arrivals(env, terminal))
    env.run(until=simulation_time)

# Run the simulation
run_simulation(SIMULATION_TIME)
# Out:
# Time 306.0180861824403: Vessel 1 is arriving.
# Time 306.0180861824403: Vessel 1 has berthed.
# Time 309.0180861824403: Crane has moved a container from Vessel 1.
# Time 313.61673789526196: Vessel 2 is arriving.
# Time 313.61673789526196: Vessel 2 has berthed.
# Time 315.0180861824403: Truck has delivered a container from Vessel 1.
# Time 316.61673789526196: Crane has moved a container from Vessel 2.
# Time 318.0180861824403: Crane has moved a container from Vessel 1.
# Time 322.61673789526196: Truck has delivered a container from Vessel 2.
# Time 324.0180861824403: Truck has delivered a container from Vessel 1.
# Time 325.61673789526196: Crane has moved a container from Vessel 2.
# Time 327.0180861824403: Crane has moved a container from Vessel 1.
# Time 331.61673789526196: Truck has delivered a container from Vessel 2.
# Time 333.0180861824403: Truck has delivered a container from Vessel 1.
# Time 334.61673789526196: Crane has moved a container from Vessel 2.
# Time 336.0180861824403: Crane has moved a container from Vessel 1.
# Time 340.61673789526196: Truck has delivered a container from Vessel 2.
# Time 342.0180861824403: Truck has delivered a container from Vessel 1.
# Time 343.61673789526196: Crane has moved a container from Vessel 2.
# Time 345.0180861824403: Crane has moved a container from Vessel 1.
# Time 349.61673789526196: Truck has delivered a container from Vessel 2.
# Time 351.0180861824403: Truck has delivered a container from Vessel 1.
# Time 352.61673789526196: Crane has moved a container from Vessel 2.
# Time 354.0180861824403: Crane has moved a container from Vessel 1.
# Time 358.61673789526196: Truck has delivered a container from Vessel 2.
# Time 360.0180861824403: Truck has delivered a container from Vessel 1.
# Time 361.61673789526196: Crane has moved a container from Vessel 2.
# Time 363.0180861824403: Crane has moved a container from Vessel 1.
# Time 367.61673789526196: Truck has delivered a container from Vessel 2.
# Time 369.0180861824403: Truck has delivered a container from Vessel 1.
# Time 370.61673789526196: Crane has moved a container from Vessel 2.
# Time 372.0180861824403: Crane has moved a container from Vessel 1.
# Time 376.61673789526196: Truck has delivered a container from Vessel 2.
# Time 378.0180861824403: Truck has delivered a container from Vessel 1.
# Time 379.61673789526196: Crane has moved a container from Vessel 2.
# Time 381.0180861824403: Crane has moved a container from Vessel 1.
# Time 385.61673789526196: Truck has delivered a container from Vessel 2.
# Time 387.0180861824403: Truck has delivered a container from Vessel 1.
# Time 388.61673789526196: Crane has moved a container from Vessel 2.
# Time 390.0180861824403: Crane has moved a container from Vessel 1.
# Time 394.61673789526196: Truck has delivered a container from Vessel 2.
# Time 396.0180861824403: Truck has delivered a container from Vessel 1.
# Time 397.61673789526196: Crane has moved a container from Vessel 2.
# Time 399.0180861824403: Crane has moved a container from Vessel 1.
# Time 403.61673789526196: Truck has delivered a container from Vessel 2.
# Time 405.0180861824403: Truck has delivered a container from Vessel 1.
# Time 406.61673789526196: Crane has moved a container from Vessel 2.
# Time 408.0180861824403: Crane has moved a container from Vessel 1.
# Time 410.10395711775163: Vessel 3 is arriving.
# Time 412.61673789526196: Truck has delivered a container from Vessel 2.
# Time 414.0180861824403: Truck has delivered a container from Vessel 1.
# Time 415.61673789526196: Crane has moved a container from Vessel 2.
# Time 417.0180861824403: Crane has moved a container from Vessel 1.
# Time 421.61673789526196: Truck has delivered a container from Vessel 2.
# Time 423.0180861824403: Truck has delivered a container from Vessel 1.
# Time 424.61673789526196: Crane has moved a container from Vessel 2.
# Time 426.0180861824403: Crane has moved a container from Vessel 1.
# Time 430.61673789526196: Truck has delivered a container from Vessel 2.
# Time 432.0180861824403: Truck has delivered a container from Vessel 1.
# Time 433.61673789526196: Crane has moved a container from Vessel 2.
# Time 435.0180861824403: Crane has moved a container from Vessel 1.
# Time 439.61673789526196: Truck has delivered a container from Vessel 2.
# Time 441.0180861824403: Truck has delivered a container from Vessel 1.
# Time 442.61673789526196: Crane has moved a container from Vessel 2.
# Time 444.0180861824403: Crane has moved a container from Vessel 1.
# Time 448.61673789526196: Truck has delivered a container from Vessel 2.
# Time 450.0180861824403: Truck has delivered a container from Vessel 1.
# Time 451.61673789526196: Crane has moved a container from Vessel 2.
# Time 453.0180861824403: Crane has moved a container from Vessel 1.
# Time 457.61673789526196: Truck has delivered a container from Vessel 2.
# Time 459.0180861824403: Truck has delivered a container from Vessel 1.
# Time 460.61673789526196: Crane has moved a container from Vessel 2.
# Time 462.0180861824403: Crane has moved a container from Vessel 1.
# Time 466.61673789526196: Truck has delivered a container from Vessel 2.
# Time 468.0180861824403: Truck has delivered a container from Vessel 1.
# Time 469.61673789526196: Crane has moved a container from Vessel 2.
# Time 471.0180861824403: Crane has moved a container from Vessel 1.
# Time 475.61673789526196: Truck has delivered a container from Vessel 2.
# Time 477.0180861824403: Truck has delivered a container from Vessel 1.
# Time 478.61673789526196: Crane has moved a container from Vessel 2.
# Time 480.0180861824403: Crane has moved a container from Vessel 1.
# Time 484.61673789526196: Truck has delivered a container from Vessel 2.
# Time 485.8798128187857: Vessel 4 is arriving.
# Time 486.0180861824403: Truck has delivered a container from Vessel 1.
# Time 487.61673789526196: Crane has moved a container from Vessel 2.
# Time 489.0180861824403: Crane has moved a container from Vessel 1.
# Time 493.61673789526196: Truck has delivered a container from Vessel 2.
# Time 495.0180861824403: Truck has delivered a container from Vessel 1.
# Time 496.61673789526196: Crane has moved a container from Vessel 2.
# Time 498.0180861824403: Crane has moved a container from Vessel 1.
# Time 502.61673789526196: Truck has delivered a container from Vessel 2.
# Time 504.0180861824403: Truck has delivered a container from Vessel 1.
# Time 505.61673789526196: Crane has moved a container from Vessel 2.
# Time 507.0180861824403: Crane has moved a container from Vessel 1.
# Time 511.61673789526196: Truck has delivered a container from Vessel 2.
# Time 513.0180861824404: Truck has delivered a container from Vessel 1.
# Time 514.616737895262: Crane has moved a container from Vessel 2.
# Time 516.0180861824404: Crane has moved a container from Vessel 1.
# Time 520.616737895262: Truck has delivered a container from Vessel 2.
# Time 522.0180861824404: Truck has delivered a container from Vessel 1.
# Time 523.616737895262: Crane has moved a container from Vessel 2.
# Time 525.0180861824404: Crane has moved a container from Vessel 1.
# Time 529.616737895262: Truck has delivered a container from Vessel 2.
# Time 531.0180861824404: Truck has delivered a container from Vessel 1.
# Time 532.616737895262: Crane has moved a container from Vessel 2.
# Time 534.0180861824404: Crane has moved a container from Vessel 1.
# Time 538.616737895262: Truck has delivered a container from Vessel 2.
# Time 540.0180861824404: Truck has delivered a container from Vessel 1.
# Time 541.616737895262: Crane has moved a container from Vessel 2.
# Time 543.0180861824404: Crane has moved a container from Vessel 1.
# Time 547.616737895262: Truck has delivered a container from Vessel 2.
# Time 549.0180861824404: Truck has delivered a container from Vessel 1.
# Time 550.616737895262: Crane has moved a container from Vessel 2.
# Time 552.0180861824404: Crane has moved a container from Vessel 1.
# Time 556.616737895262: Truck has delivered a container from Vessel 2.
# Time 558.0180861824404: Truck has delivered a container from Vessel 1.
# Time 559.616737895262: Crane has moved a container from Vessel 2.
# Time 561.0180861824404: Crane has moved a container from Vessel 1.
# Time 565.616737895262: Truck has delivered a container from Vessel 2.
# Time 567.0180861824404: Truck has delivered a container from Vessel 1.
# Time 568.616737895262: Crane has moved a container from Vessel 2.
# Time 570.0180861824404: Crane has moved a container from Vessel 1.
# Time 574.616737895262: Truck has delivered a container from Vessel 2.
# Time 576.0180861824404: Truck has delivered a container from Vessel 1.
# Time 577.616737895262: Crane has moved a container from Vessel 2.
# Time 579.0180861824404: Crane has moved a container from Vessel 1.
# Time 583.616737895262: Truck has delivered a container from Vessel 2.
# Time 585.0180861824404: Truck has delivered a container from Vessel 1.
# Time 586.616737895262: Crane has moved a container from Vessel 2.
# Time 588.0180861824404: Crane has moved a container from Vessel 1.
# Time 592.616737895262: Truck has delivered a container from Vessel 2.
# Time 594.0180861824404: Truck has delivered a container from Vessel 1.
# Time 595.616737895262: Crane has moved a container from Vessel 2.
# Time 597.0180861824404: Crane has moved a container from Vessel 1.
# Time 601.616737895262: Truck has delivered a container from Vessel 2.
# Time 603.0180861824404: Truck has delivered a container from Vessel 1.
# Time 604.616737895262: Crane has moved a container from Vessel 2.
# Time 606.0180861824404: Crane has moved a container from Vessel 1.
# Time 610.616737895262: Truck has delivered a container from Vessel 2.
# Time 612.0180861824404: Truck has delivered a container from Vessel 1.
# Time 613.616737895262: Crane has moved a container from Vessel 2.
# Time 615.0180861824404: Crane has moved a container from Vessel 1.
# Time 619.616737895262: Truck has delivered a container from Vessel 2.
# Time 621.0180861824404: Truck has delivered a container from Vessel 1.
# Time 622.616737895262: Crane has moved a container from Vessel 2.
# Time 624.0180861824404: Crane has moved a container from Vessel 1.
# Time 628.616737895262: Truck has delivered a container from Vessel 2.
# Time 630.0180861824404: Truck has delivered a container from Vessel 1.
# Time 631.616737895262: Crane has moved a container from Vessel 2.
# Time 633.0180861824404: Crane has moved a container from Vessel 1.
# Time 637.616737895262: Truck has delivered a container from Vessel 2.
# Time 639.0180861824404: Truck has delivered a container from Vessel 1.
# Time 640.616737895262: Crane has moved a container from Vessel 2.
# Time 642.0180861824404: Crane has moved a container from Vessel 1.
# Time 646.616737895262: Truck has delivered a container from Vessel 2.
# Time 648.0180861824404: Truck has delivered a container from Vessel 1.
# Time 649.616737895262: Crane has moved a container from Vessel 2.
# Time 651.0180861824404: Crane has moved a container from Vessel 1.
# Time 655.616737895262: Truck has delivered a container from Vessel 2.
# Time 657.0180861824404: Truck has delivered a container from Vessel 1.
# Time 658.616737895262: Crane has moved a container from Vessel 2.
# Time 660.0180861824404: Crane has moved a container from Vessel 1.
# Time 664.616737895262: Truck has delivered a container from Vessel 2.
# Time 666.0180861824404: Truck has delivered a container from Vessel 1.
# Time 667.616737895262: Crane has moved a container from Vessel 2.
# Time 669.0180861824404: Crane has moved a container from Vessel 1.
# Time 673.616737895262: Truck has delivered a container from Vessel 2.
# Time 675.0180861824404: Truck has delivered a container from Vessel 1.
# Time 676.616737895262: Crane has moved a container from Vessel 2.
# Time 678.0180861824404: Crane has moved a container from Vessel 1.
# Time 682.616737895262: Truck has delivered a container from Vessel 2.
# Time 684.0180861824404: Truck has delivered a container from Vessel 1.
# Time 685.616737895262: Crane has moved a container from Vessel 2.
# Time 687.0180861824404: Crane has moved a container from Vessel 1.
# Time 691.616737895262: Truck has delivered a container from Vessel 2.
# Time 693.0180861824404: Truck has delivered a container from Vessel 1.
# Time 694.616737895262: Crane has moved a container from Vessel 2.
# Time 696.0180861824404: Crane has moved a container from Vessel 1.
# Time 700.616737895262: Truck has delivered a container from Vessel 2.
# Time 702.0180861824404: Truck has delivered a container from Vessel 1.
# Time 703.616737895262: Crane has moved a container from Vessel 2.
# Time 705.0180861824404: Crane has moved a container from Vessel 1.
# Time 709.616737895262: Truck has delivered a container from Vessel 2.
# Time 711.0180861824404: Truck has delivered a container from Vessel 1.
# Time 712.616737895262: Crane has moved a container from Vessel 2.
# Time 714.0180861824404: Crane has moved a container from Vessel 1.
# Time 718.616737895262: Truck has delivered a container from Vessel 2.
# Time 720.0180861824404: Truck has delivered a container from Vessel 1.
# Time 721.616737895262: Crane has moved a container from Vessel 2.
# Time 723.0180861824404: Crane has moved a container from Vessel 1.
# Time 727.616737895262: Truck has delivered a container from Vessel 2.
# Time 729.0180861824404: Truck has delivered a container from Vessel 1.
# Time 730.616737895262: Crane has moved a container from Vessel 2.
# Time 732.0180861824404: Crane has moved a container from Vessel 1.
# Time 736.616737895262: Truck has delivered a container from Vessel 2.
# Time 738.0180861824404: Truck has delivered a container from Vessel 1.
# Time 739.616737895262: Crane has moved a container from Vessel 2.
# Time 741.0180861824404: Crane has moved a container from Vessel 1.
# Time 745.616737895262: Truck has delivered a container from Vessel 2.
# Time 747.0180861824404: Truck has delivered a container from Vessel 1.
# Time 748.616737895262: Crane has moved a container from Vessel 2.
# Time 750.0180861824404: Crane has moved a container from Vessel 1.
# Time 754.616737895262: Truck has delivered a container from Vessel 2.
# Time 756.0180861824404: Truck has delivered a container from Vessel 1.
# Time 757.616737895262: Crane has moved a container from Vessel 2.
# Time 759.0180861824404: Crane has moved a container from Vessel 1.
# Time 763.616737895262: Truck has delivered a container from Vessel 2.
# Time 765.0180861824404: Truck has delivered a container from Vessel 1.
# Time 766.616737895262: Crane has moved a container from Vessel 2.
# Time 768.0180861824404: Crane has moved a container from Vessel 1.
# Time 772.616737895262: Truck has delivered a container from Vessel 2.
# Time 774.0180861824404: Truck has delivered a container from Vessel 1.
# Time 775.616737895262: Crane has moved a container from Vessel 2.
# Time 777.0180861824404: Crane has moved a container from Vessel 1.
# Time 781.616737895262: Truck has delivered a container from Vessel 2.
# Time 783.0180861824404: Truck has delivered a container from Vessel 1.
# Time 784.616737895262: Crane has moved a container from Vessel 2.
# Time 786.0180861824404: Crane has moved a container from Vessel 1.
# Time 790.616737895262: Truck has delivered a container from Vessel 2.
# Time 792.0180861824404: Truck has delivered a container from Vessel 1.
# Time 793.616737895262: Crane has moved a container from Vessel 2.
# Time 795.0180861824404: Crane has moved a container from Vessel 1.
# Time 799.616737895262: Truck has delivered a container from Vessel 2.
# Time 801.0180861824404: Truck has delivered a container from Vessel 1.
# Time 802.616737895262: Crane has moved a container from Vessel 2.
# Time 804.0180861824404: Crane has moved a container from Vessel 1.
# Time 808.616737895262: Truck has delivered a container from Vessel 2.
# Time 810.0180861824404: Truck has delivered a container from Vessel 1.
# Time 811.616737895262: Crane has moved a container from Vessel 2.
# Time 813.0180861824404: Crane has moved a container from Vessel 1.
# Time 817.616737895262: Truck has delivered a container from Vessel 2.
# Time 819.0180861824404: Truck has delivered a container from Vessel 1.
# Time 820.616737895262: Crane has moved a container from Vessel 2.
# Time 822.0180861824404: Crane has moved a container from Vessel 1.
# Time 826.616737895262: Truck has delivered a container from Vessel 2.
# Time 828.0180861824404: Truck has delivered a container from Vessel 1.
# Time 829.616737895262: Crane has moved a container from Vessel 2.
# Time 831.0180861824404: Crane has moved a container from Vessel 1.
# Time 835.616737895262: Truck has delivered a container from Vessel 2.
# Time 837.0180861824404: Truck has delivered a container from Vessel 1.
# Time 838.616737895262: Crane has moved a container from Vessel 2.
# Time 840.0180861824404: Crane has moved a container from Vessel 1.
# Time 844.616737895262: Truck has delivered a container from Vessel 2.
# Time 846.0180861824404: Truck has delivered a container from Vessel 1.
# Time 847.616737895262: Crane has moved a container from Vessel 2.
# Time 849.0180861824404: Crane has moved a container from Vessel 1.
# Time 853.616737895262: Truck has delivered a container from Vessel 2.
# Time 855.0180861824404: Truck has delivered a container from Vessel 1.
# Time 856.616737895262: Crane has moved a container from Vessel 2.
# Time 858.0180861824404: Crane has moved a container from Vessel 1.
# Time 862.616737895262: Truck has delivered a container from Vessel 2.
# Time 864.0180861824404: Truck has delivered a container from Vessel 1.
# Time 865.616737895262: Crane has moved a container from Vessel 2.
# Time 867.0180861824404: Crane has moved a container from Vessel 1.
# Time 871.616737895262: Truck has delivered a container from Vessel 2.
# Time 873.0180861824404: Truck has delivered a container from Vessel 1.
# Time 874.616737895262: Crane has moved a container from Vessel 2.
# Time 876.0180861824404: Crane has moved a container from Vessel 1.
# Time 880.616737895262: Truck has delivered a container from Vessel 2.
# Time 882.0180861824404: Truck has delivered a container from Vessel 1.
# Time 883.616737895262: Crane has moved a container from Vessel 2.
# Time 885.0180861824404: Crane has moved a container from Vessel 1.
# Time 885.9576146612105: Vessel 5 is arriving.
# Time 889.616737895262: Truck has delivered a container from Vessel 2.
# Time 891.0180861824404: Truck has delivered a container from Vessel 1.
# Time 892.616737895262: Crane has moved a container from Vessel 2.
# Time 894.0180861824404: Crane has moved a container from Vessel 1.
# Time 898.616737895262: Truck has delivered a container from Vessel 2.
# Time 900.0180861824404: Truck has delivered a container from Vessel 1.
# Time 901.616737895262: Crane has moved a container from Vessel 2.
# Time 903.0180861824404: Crane has moved a container from Vessel 1.
# Time 907.616737895262: Truck has delivered a container from Vessel 2.
# Time 909.0180861824404: Truck has delivered a container from Vessel 1.
# Time 910.616737895262: Crane has moved a container from Vessel 2.
# Time 912.0180861824404: Crane has moved a container from Vessel 1.
# Time 916.616737895262: Truck has delivered a container from Vessel 2.
# Time 918.0180861824404: Truck has delivered a container from Vessel 1.
# Time 919.616737895262: Crane has moved a container from Vessel 2.
# Time 921.0180861824404: Crane has moved a container from Vessel 1.
# Time 925.616737895262: Truck has delivered a container from Vessel 2.
# Time 927.0180861824404: Truck has delivered a container from Vessel 1.
# Time 928.616737895262: Crane has moved a container from Vessel 2.
# Time 930.0180861824404: Crane has moved a container from Vessel 1.
# Time 934.616737895262: Truck has delivered a container from Vessel 2.
# Time 936.0180861824404: Truck has delivered a container from Vessel 1.
# Time 937.616737895262: Crane has moved a container from Vessel 2.
# Time 939.0180861824404: Crane has moved a container from Vessel 1.
# Time 943.616737895262: Truck has delivered a container from Vessel 2.
# Time 945.0180861824404: Truck has delivered a container from Vessel 1.
# Time 946.616737895262: Crane has moved a container from Vessel 2.
# Time 948.0180861824404: Crane has moved a container from Vessel 1.
# Time 952.616737895262: Truck has delivered a container from Vessel 2.
# Time 954.0180861824404: Truck has delivered a container from Vessel 1.
# Time 955.616737895262: Crane has moved a container from Vessel 2.
# Time 957.0180861824404: Crane has moved a container from Vessel 1.
# Time 961.616737895262: Truck has delivered a container from Vessel 2.
# Time 963.0180861824404: Truck has delivered a container from Vessel 1.
# Time 964.616737895262: Crane has moved a container from Vessel 2.
# Time 966.0180861824404: Crane has moved a container from Vessel 1.
# Time 970.616737895262: Truck has delivered a container from Vessel 2.
# Time 972.0180861824404: Truck has delivered a container from Vessel 1.
# Time 973.616737895262: Crane has moved a container from Vessel 2.
# Time 975.0180861824404: Crane has moved a container from Vessel 1.
# Time 979.616737895262: Truck has delivered a container from Vessel 2.
# Time 981.0180861824404: Truck has delivered a container from Vessel 1.
# Time 982.616737895262: Crane has moved a container from Vessel 2.
# Time 984.0180861824404: Crane has moved a container from Vessel 1.
# Time 988.616737895262: Truck has delivered a container from Vessel 2.
# Time 990.0180861824404: Truck has delivered a container from Vessel 1.
# Time 991.616737895262: Crane has moved a container from Vessel 2.
# Time 993.0180861824404: Crane has moved a container from Vessel 1.
# Time 997.616737895262: Truck has delivered a container from Vessel 2.
# Time 999.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1000.616737895262: Crane has moved a container from Vessel 2.
# Time 1002.0180861824404: Crane has moved a container from Vessel 1.
# Time 1006.616737895262: Truck has delivered a container from Vessel 2.
# Time 1008.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1009.616737895262: Crane has moved a container from Vessel 2.
# Time 1011.0180861824404: Crane has moved a container from Vessel 1.
# Time 1015.616737895262: Truck has delivered a container from Vessel 2.
# Time 1017.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1018.616737895262: Crane has moved a container from Vessel 2.
# Time 1020.0180861824404: Crane has moved a container from Vessel 1.
# Time 1024.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1026.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1027.6167378952618: Crane has moved a container from Vessel 2.
# Time 1029.0180861824404: Crane has moved a container from Vessel 1.
# Time 1033.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1035.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1036.6167378952618: Crane has moved a container from Vessel 2.
# Time 1038.0180861824404: Crane has moved a container from Vessel 1.
# Time 1042.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1044.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1045.6167378952618: Crane has moved a container from Vessel 2.
# Time 1047.0180861824404: Crane has moved a container from Vessel 1.
# Time 1051.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1053.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1054.6167378952618: Crane has moved a container from Vessel 2.
# Time 1056.0180861824404: Crane has moved a container from Vessel 1.
# Time 1060.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1062.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1063.6167378952618: Crane has moved a container from Vessel 2.
# Time 1065.0180861824404: Crane has moved a container from Vessel 1.
# Time 1069.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1071.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1072.6167378952618: Crane has moved a container from Vessel 2.
# Time 1074.0180861824404: Crane has moved a container from Vessel 1.
# Time 1078.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1080.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1081.6167378952618: Crane has moved a container from Vessel 2.
# Time 1083.0180861824404: Crane has moved a container from Vessel 1.
# Time 1087.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1089.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1090.6167378952618: Crane has moved a container from Vessel 2.
# Time 1092.0180861824404: Crane has moved a container from Vessel 1.
# Time 1096.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1098.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1099.6167378952618: Crane has moved a container from Vessel 2.
# Time 1101.0180861824404: Crane has moved a container from Vessel 1.
# Time 1105.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1107.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1108.6167378952618: Crane has moved a container from Vessel 2.
# Time 1110.0180861824404: Crane has moved a container from Vessel 1.
# Time 1114.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1116.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1117.6167378952618: Crane has moved a container from Vessel 2.
# Time 1119.0180861824404: Crane has moved a container from Vessel 1.
# Time 1123.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1125.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1126.6167378952618: Crane has moved a container from Vessel 2.
# Time 1128.0180861824404: Crane has moved a container from Vessel 1.
# Time 1132.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1134.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1135.6167378952618: Crane has moved a container from Vessel 2.
# Time 1137.0180861824404: Crane has moved a container from Vessel 1.
# Time 1141.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1143.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1144.6167378952618: Crane has moved a container from Vessel 2.
# Time 1146.0180861824404: Crane has moved a container from Vessel 1.
# Time 1150.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1152.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1153.6167378952618: Crane has moved a container from Vessel 2.
# Time 1155.0180861824404: Crane has moved a container from Vessel 1.
# Time 1159.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1161.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1162.6167378952618: Crane has moved a container from Vessel 2.
# Time 1164.0180861824404: Crane has moved a container from Vessel 1.
# Time 1168.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1170.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1171.6167378952618: Crane has moved a container from Vessel 2.
# Time 1173.0180861824404: Crane has moved a container from Vessel 1.
# Time 1177.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1179.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1180.6167378952618: Crane has moved a container from Vessel 2.
# Time 1182.0180861824404: Crane has moved a container from Vessel 1.
# Time 1186.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1188.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1189.6167378952618: Crane has moved a container from Vessel 2.
# Time 1191.0180861824404: Crane has moved a container from Vessel 1.
# Time 1195.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1197.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1198.6167378952618: Crane has moved a container from Vessel 2.
# Time 1200.0180861824404: Crane has moved a container from Vessel 1.
# Time 1204.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1206.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1207.6167378952618: Crane has moved a container from Vessel 2.
# Time 1209.0180861824404: Crane has moved a container from Vessel 1.
# Time 1213.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1215.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1216.6167378952618: Crane has moved a container from Vessel 2.
# Time 1218.0180861824404: Crane has moved a container from Vessel 1.
# Time 1222.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1224.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1224.7095173007883: Vessel 6 is arriving.
# Time 1225.6167378952618: Crane has moved a container from Vessel 2.
# Time 1227.0180861824404: Crane has moved a container from Vessel 1.
# Time 1231.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1233.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1234.6167378952618: Crane has moved a container from Vessel 2.
# Time 1236.0180861824404: Crane has moved a container from Vessel 1.
# Time 1240.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1242.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1243.6167378952618: Crane has moved a container from Vessel 2.
# Time 1245.0180861824404: Crane has moved a container from Vessel 1.
# Time 1249.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1251.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1252.6167378952618: Crane has moved a container from Vessel 2.
# Time 1254.0180861824404: Crane has moved a container from Vessel 1.
# Time 1258.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1260.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1261.6167378952618: Crane has moved a container from Vessel 2.
# Time 1263.0180861824404: Crane has moved a container from Vessel 1.
# Time 1267.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1269.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1270.6167378952618: Crane has moved a container from Vessel 2.
# Time 1272.0180861824404: Crane has moved a container from Vessel 1.
# Time 1276.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1278.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1279.6167378952618: Crane has moved a container from Vessel 2.
# Time 1281.0180861824404: Crane has moved a container from Vessel 1.
# Time 1285.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1287.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1288.6167378952618: Crane has moved a container from Vessel 2.
# Time 1290.0180861824404: Crane has moved a container from Vessel 1.
# Time 1294.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1296.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1297.6167378952618: Crane has moved a container from Vessel 2.
# Time 1299.0180861824404: Crane has moved a container from Vessel 1.
# Time 1303.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1305.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1306.6167378952618: Crane has moved a container from Vessel 2.
# Time 1308.0180861824404: Crane has moved a container from Vessel 1.
# Time 1312.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1314.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1315.6167378952618: Crane has moved a container from Vessel 2.
# Time 1317.0180861824404: Crane has moved a container from Vessel 1.
# Time 1321.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1323.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1324.6167378952618: Crane has moved a container from Vessel 2.
# Time 1326.0180861824404: Crane has moved a container from Vessel 1.
# Time 1330.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1332.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1333.6167378952618: Crane has moved a container from Vessel 2.
# Time 1335.0180861824404: Crane has moved a container from Vessel 1.
# Time 1339.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1341.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1342.6167378952618: Crane has moved a container from Vessel 2.
# Time 1344.0180861824404: Crane has moved a container from Vessel 1.
# Time 1348.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1350.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1351.6167378952618: Crane has moved a container from Vessel 2.
# Time 1353.0180861824404: Crane has moved a container from Vessel 1.
# Time 1357.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1359.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1360.6167378952618: Crane has moved a container from Vessel 2.
# Time 1362.0180861824404: Crane has moved a container from Vessel 1.
# Time 1366.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1368.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1369.6167378952618: Crane has moved a container from Vessel 2.
# Time 1371.0180861824404: Crane has moved a container from Vessel 1.
# Time 1375.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1377.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1378.6167378952618: Crane has moved a container from Vessel 2.
# Time 1380.0180861824404: Crane has moved a container from Vessel 1.
# Time 1384.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1386.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1387.6167378952618: Crane has moved a container from Vessel 2.
# Time 1389.0180861824404: Crane has moved a container from Vessel 1.
# Time 1393.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1395.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1396.6167378952618: Crane has moved a container from Vessel 2.
# Time 1398.0180861824404: Crane has moved a container from Vessel 1.
# Time 1402.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1404.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1405.6167378952618: Crane has moved a container from Vessel 2.
# Time 1407.0180861824404: Crane has moved a container from Vessel 1.
# Time 1411.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1413.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1414.6167378952618: Crane has moved a container from Vessel 2.
# Time 1416.0180861824404: Crane has moved a container from Vessel 1.
# Time 1420.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1422.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1423.6167378952618: Crane has moved a container from Vessel 2.
# Time 1425.0180861824404: Crane has moved a container from Vessel 1.
# Time 1429.6167378952618: Truck has delivered a container from Vessel 2.
# Time 1431.0180861824404: Truck has delivered a container from Vessel 1.
# Time 1432.6167378952618: Crane has moved a container from Vessel 2.
# Time 1434.0180861824404: Crane has moved a container from Vessel 1.
# Time 1438.6167378952618: Truck has delivered a container from Vessel 2.
